# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import random

# %%
n=int(input())
xcord=random.randint(1000,size=(n))
ycord=random.randint(1000,size=(n))
plt.plot(xcord,ycord)
plt.show()
